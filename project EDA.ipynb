# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time

# Set up headless Chrome browser
options = Options()
options.add_argument("--headless")  # Set to False to see browser in action
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# List to store all DataFrames
df_list = []

# Loop through pages 1 to 4
for page in range(1, 5):
    url = f"https://www.metacritic.com/browse/game/all/adventure/all-time/metascore/?releaseYearMin=1991&releaseYearMax=2011&genre=adventure&page={page}"
    print(f"Scraping page {page}...")
    
    driver.get(url)
    time.sleep(3)  # Wait for JavaScript to load

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Extract titles
    titles = soup.find_all('div', class_='c-finderProductCard_title')
    titles_a = [t.find_all("span")[1].text.strip() for t in titles if len(t.find_all("span")) > 1]

    # Extract dates and ratings
    dates = soup.find_all('div', class_='c-finderProductCard_meta')
    dates_a = []
    rates_a = []

    for d in dates:
        span_date = d.find('span', class_='u-text-uppercase')
        dates_a.append(span_date.text.strip() if span_date else None)

        span_rating = d.find('span', class_='u-text-capitalize')
        rates_a.append(span_rating.next_sibling.strip() if span_rating and span_rating.next_sibling else None)

    # Extract descriptions
    descriptions = soup.find_all('div', class_='c-finderProductCard_description')
    descriptions_a = [desc.find('span').text.strip() if desc.find('span') else None for desc in descriptions]

    # Extract scores
    scores = soup.find_all('div', class_='c-siteReviewScore')
    scores_a = [score.get("aria-label") for score in scores]

    # Debugging: check list lengths
    print(f"Titles: {len(titles_a)}, Dates: {len(dates_a)}, Ratings: {len(rates_a)}, Descriptions: {len(descriptions_a)}, Scores: {len(scores_a)}")

    # Trim to shortest length
    min_len = min(len(titles_a), len(dates_a), len(rates_a), len(descriptions_a), len(scores_a))

    data = zip(
        titles_a[:min_len],
        dates_a[:min_len],
        rates_a[:min_len],
        descriptions_a[:min_len],
        scores_a[:min_len]
    )

    # Create DataFrame
    df = pd.DataFrame(data, columns=['Title', 'Date', 'Rating', 'Description', 'Score'])
    df_list.append(df)

# Close the browser
driver.quit()

# Combine all data into one DataFrame
final_df = pd.concat(df_list, ignore_index=True)

# Display the first few rows
print(final_df.head())
# Out:
# Scraping page 1...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 2...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 3...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 4...
# Titles: 11, Dates: 22, Ratings: 22, Descriptions: 11, Scores: 11
#                                        Title          Date Rating  \
# 0  Zack & Wiki: Quest for Barbaros' Treasure  Oct 23, 2007      E
# 1                                     flower          None   None
# 2             Ghost Trick: Phantom Detective  Feb 12, 2009      E
# 3                The Book of Unwritten Tales          None   None
# 4                   Prince of Persia Classic  Jan 11, 2011      T
#
#                                          Description                    Score
# 0  Legend has it that a revered pirate named Barb...  Metascore 87 out of 100
# 1  [Playstation Network]  The pioneers that broug...  Metascore 87 out of 100
# 2  Ghost Trick is a story of mystery and intrigue...  Metascore 83 out of 100
# 3  In a world torn by war, the aged gremlin archa...  Metascore 82 out of 100
# 4  [Xbox Live Arcade]  While the Sultan of Persia...  Metascore 82 out of 100

# %%
final_df
# Out:
#                                                Title          Date Rating  \
# 0          Zack & Wiki: Quest for Barbaros' Treasure  Oct 23, 2007      E
# 1                                             flower          None   None
# 2                     Ghost Trick: Phantom Detective  Feb 12, 2009      E
# 3                        The Book of Unwritten Tales          None   None
# 4                           Prince of Persia Classic  Jan 11, 2011      T
# ..                                               ...           ...    ...
# 78  CSI: Crime Scene Investigation: Fatal Conspiracy  Dec 31, 2001      M
# 79                      Prison Break: The Conspiracy          None   None
# 80                                          Inkheart  Jun 11, 2008      T
# 81                                              NCIS          None   None
# 82                                   Survivor (2001)  Jan 27, 2009   E10+
#
#                                           Description                    Score
# 0   Legend has it that a revered pirate named Barb...  Metascore 87 out of 100
# 1   [Playstation Network]  The pioneers that broug...  Metascore 87 out of 100
# 2   Ghost Trick is a story of mystery and intrigue...  Metascore 83 out of 100
# 3   In a world torn by war, the aged gremlin archa...  Metascore 82 out of 100
# 4   [Xbox Live Arcade]  While the Sultan of Persia...  Metascore 82 out of 100
# ..                                                ...                      ...
# 78  CSI: Fatal Conspiracy features five new connec...  Metascore 42 out of 100
# 79  Prison Break - The Conspiracy takes you inside...  Metascore 40 out of 100
# 80  Based on the feature film adaptation of the be...  Metascore 39 out of 100
# 81  NCIS is now available for the first time ever ...  Metascore 35 out of 100
# 82  Play as any of the actual Pulau Tiga and Austr...  Metascore 26 out of 100
#
# [83 rows x 5 columns]

# %%
final_df_2 = final_df.dropna()

# %%
final_df_2
# Out:
#                                                 Title          Date Rating  \
# 0           Zack & Wiki: Quest for Barbaros' Treasure  Oct 23, 2007      E
# 2                      Ghost Trick: Phantom Detective  Feb 12, 2009      E
# 4                            Prince of Persia Classic  Jan 11, 2011      T
# 6                                Hotel Dusk: Room 215  Oct 28, 2011      T
# 8                                    The Devil Inside  Jun 13, 2007      T
# 12                                 Beyond Atlantis II  Jan 22, 2007      T
# 14                             Missing: Since January   Jul 5, 2010      T
# 16                          Space Pirates and Zombies   Nov 9, 2000      M
# 18                     Ankh: Curse of the Scarab King  May 21, 2008      M
# 20                     Dive: The Medes Islands Secret  Oct 29, 2008      M
# 22                              The Egyptian Prophecy   Apr 3, 2007      E
# 26        Riddle of the Sphinx: An Egyptian Adventure  Oct 14, 2009      E
# 28                     Nostradamus: The Last Prophecy   Dec 5, 2000      E
# 30                Sherlock Holmes: The Silver Earring   Mar 3, 2008      T
# 32  Teenage Zombies: Invasion of the Alien Brain T...  Sep 30, 2007   E10+
# 34                                      In Cold Blood  Apr 15, 2008      T
# 36                             Nibiru: Age of Secrets  Sep 28, 2004      T
# 38                         Disney's A Christmas Carol   Feb 5, 2008      T
# 40  The Adventures of Jimmy Neutron Boy Genius: At...  Apr 15, 2008   E10+
# 42                                    Stupid Invaders  Aug 11, 2009      M
# 44   Nancy Drew: The Deadly Secret of Olde World Park  Mar 25, 2001      T
# 46                 The Adventures of Tintin: The Game   Oct 9, 2007      E
# 50                                      Traitors Gate  Mar 20, 2007      E
# 52            Road to India: Between Hell and Nirvana  Apr 30, 2000      E
# 56                                   The Black Mirror  Sep 16, 2001      E
# 58                Of Light and Darkness: The Prophecy  Oct 24, 2006   E10+
# 60  Chronicles of Mystery: Curse of the Ancient Te...   Feb 5, 2008   E10+
# 62                                           The Ward  Mar 19, 2004      E
# 64                                          Next Life  Oct 20, 2003      M
# 66                                 Crime Scene (2009)   Jan 2, 2001      E
# 68                                        Gobliiins 4  Mar 31, 1998      T
# 70        Darkness Within: In Pursuit of Loath Nolder  Jun 18, 2008      E
# 72      CSI: Crime Scene Investigation: Deadly Intent  Oct 27, 2009      M
# 74                       Code Lyoko: Fall of X.A.N.A.   Jul 3, 2007      T
# 76                  Jake Hunter: Detective Chronicles  Jun 20, 2008      E
# 78   CSI: Crime Scene Investigation: Fatal Conspiracy  Dec 31, 2001      M
# 80                                           Inkheart  Jun 11, 2008      T
# 82                                    Survivor (2001)  Jan 27, 2009   E10+
#
#                                           Description                    Score
# 0   Legend has it that a revered pirate named Barb...  Metascore 87 out of 100
# 2   Ghost Trick is a story of mystery and intrigue...  Metascore 83 out of 100
# 4   [Xbox Live Arcade]  While the Sultan of Persia...  Metascore 82 out of 100
# 6   Los Angeles, 1979. You are Kyle Hyde, an ex-co...  Metascore 78 out of 100
# 8   The game features you as the star of a live Ho...  Metascore 76 out of 100
# 12  A young archeologist searches for the existenc...  Metascore 75 out of 100
# 14  Journalist, Jack Lorski, and his companion dis...  Metascore 75 out of 100
# 16  Space Pirates and Zombies takes place far enou...  Metascore 74 out of 100
# 18  After a wild party at Pharaoh‘s pyramid, young...  Metascore 74 out of 100
# 20  Dive: The Medes Islands Secret recreates under...  Metascore 74 out of 100
# 22  (Also known as "Egypt III: The Fate of Ramses"...  Metascore 73 out of 100
# 26  Riddle of the Sphinx makes up for its technica...  Metascore 72 out of 100
# 28  Nostradamus: The Last Prophecy is set in 16th ...  Metascore 70 out of 100
# 30  (Also known as "Sherlock Holmes: The Case of t...  Metascore 68 out of 100
# 32  The Earth is under attack by a horde of Alien ...  Metascore 67 out of 100
# 34  Travel the world controlling M16 Secret Britis...  Metascore 67 out of 100
# 36  Martin Holan, a linguistics and archeology stu...  Metascore 66 out of 100
# 38  This is a puzzle-adventure game of the the fea...  Metascore 66 out of 100
# 40  Jimmy Neutron: Attack of the Twonkies is jam-p...  Metascore 65 out of 100
# 42  State-of-the-art toilet humor! First graphic a...  Metascore 65 out of 100
# 44  Olde World, a multimillion dollar vacation spo...  Metascore 64 out of 100
# 46  The Adventures of Tintin is a game based off i...  Metascore 63 out of 100
# 50  You'll need to learn lock picking, security-co...  Metascore 63 out of 100
# 52  When Fred Reynolds left his fiancée at the air...  Metascore 61 out of 100
# 56  British nobleman, Samuel Gordon, has just retu...  Metascore 58 out of 100
# 58  A real-time surrealistic adventure in which th...  Metascore 58 out of 100
# 60  Sylvie, a young archaeologist, is about to beg...  Metascore 57 out of 100
# 62  The Ward has some good puzzles and some intere...  Metascore 57 out of 100
# 64  Adam Raichl is instantly killed in a horrific ...  Metascore 56 out of 100
# 66  Matt Simmons is a fresh recruit as a forensic ...  Metascore 54 out of 100
# 68  Gobliiins games mix elements of adventure and ...  Metascore 54 out of 100
# 70  As police detective Howard E. Loreid, players ...  Metascore 52 out of 100
# 72  In Sin City there are no secrets, only hidden ...  Metascore 51 out of 100
# 74  A brand-new tale, based on the fourth season o...  Metascore 51 out of 100
# 76  Hone your detective skills by interviewing wit...  Metascore 47 out of 100
# 78  CSI: Fatal Conspiracy features five new connec...  Metascore 42 out of 100
# 80  Based on the feature film adaptation of the be...  Metascore 39 out of 100
# 82  Play as any of the actual Pulau Tiga and Austr...  Metascore 26 out of 100

# %%
final_df_3 = final_df_2.reset_index(drop=True)

# %%
final_df_3
# Out:
#                                                 Title          Date Rating  \
# 0           Zack & Wiki: Quest for Barbaros' Treasure  Oct 23, 2007      E
# 1                      Ghost Trick: Phantom Detective  Feb 12, 2009      E
# 2                            Prince of Persia Classic  Jan 11, 2011      T
# 3                                Hotel Dusk: Room 215  Oct 28, 2011      T
# 4                                    The Devil Inside  Jun 13, 2007      T
# 5                                  Beyond Atlantis II  Jan 22, 2007      T
# 6                              Missing: Since January   Jul 5, 2010      T
# 7                           Space Pirates and Zombies   Nov 9, 2000      M
# 8                      Ankh: Curse of the Scarab King  May 21, 2008      M
# 9                      Dive: The Medes Islands Secret  Oct 29, 2008      M
# 10                              The Egyptian Prophecy   Apr 3, 2007      E
# 11        Riddle of the Sphinx: An Egyptian Adventure  Oct 14, 2009      E
# 12                     Nostradamus: The Last Prophecy   Dec 5, 2000      E
# 13                Sherlock Holmes: The Silver Earring   Mar 3, 2008      T
# 14  Teenage Zombies: Invasion of the Alien Brain T...  Sep 30, 2007   E10+
# 15                                      In Cold Blood  Apr 15, 2008      T
# 16                             Nibiru: Age of Secrets  Sep 28, 2004      T
# 17                         Disney's A Christmas Carol   Feb 5, 2008      T
# 18  The Adventures of Jimmy Neutron Boy Genius: At...  Apr 15, 2008   E10+
# 19                                    Stupid Invaders  Aug 11, 2009      M
# 20   Nancy Drew: The Deadly Secret of Olde World Park  Mar 25, 2001      T
# 21                 The Adventures of Tintin: The Game   Oct 9, 2007      E
# 22                                      Traitors Gate  Mar 20, 2007      E
# 23            Road to India: Between Hell and Nirvana  Apr 30, 2000      E
# 24                                   The Black Mirror  Sep 16, 2001      E
# 25                Of Light and Darkness: The Prophecy  Oct 24, 2006   E10+
# 26  Chronicles of Mystery: Curse of the Ancient Te...   Feb 5, 2008   E10+
# 27                                           The Ward  Mar 19, 2004      E
# 28                                          Next Life  Oct 20, 2003      M
# 29                                 Crime Scene (2009)   Jan 2, 2001      E
# 30                                        Gobliiins 4  Mar 31, 1998      T
# 31        Darkness Within: In Pursuit of Loath Nolder  Jun 18, 2008      E
# 32      CSI: Crime Scene Investigation: Deadly Intent  Oct 27, 2009      M
# 33                       Code Lyoko: Fall of X.A.N.A.   Jul 3, 2007      T
# 34                  Jake Hunter: Detective Chronicles  Jun 20, 2008      E
# 35   CSI: Crime Scene Investigation: Fatal Conspiracy  Dec 31, 2001      M
# 36                                           Inkheart  Jun 11, 2008      T
# 37                                    Survivor (2001)  Jan 27, 2009   E10+
#
#                                           Description                    Score
# 0   Legend has it that a revered pirate named Barb...  Metascore 87 out of 100
# 1   Ghost Trick is a story of mystery and intrigue...  Metascore 83 out of 100
# 2   [Xbox Live Arcade]  While the Sultan of Persia...  Metascore 82 out of 100
# 3   Los Angeles, 1979. You are Kyle Hyde, an ex-co...  Metascore 78 out of 100
# 4   The game features you as the star of a live Ho...  Metascore 76 out of 100
# 5   A young archeologist searches for the existenc...  Metascore 75 out of 100
# 6   Journalist, Jack Lorski, and his companion dis...  Metascore 75 out of 100
# 7   Space Pirates and Zombies takes place far enou...  Metascore 74 out of 100
# 8   After a wild party at Pharaoh‘s pyramid, young...  Metascore 74 out of 100
# 9   Dive: The Medes Islands Secret recreates under...  Metascore 74 out of 100
# 10  (Also known as "Egypt III: The Fate of Ramses"...  Metascore 73 out of 100
# 11  Riddle of the Sphinx makes up for its technica...  Metascore 72 out of 100
# 12  Nostradamus: The Last Prophecy is set in 16th ...  Metascore 70 out of 100
# 13  (Also known as "Sherlock Holmes: The Case of t...  Metascore 68 out of 100
# 14  The Earth is under attack by a horde of Alien ...  Metascore 67 out of 100
# 15  Travel the world controlling M16 Secret Britis...  Metascore 67 out of 100
# 16  Martin Holan, a linguistics and archeology stu...  Metascore 66 out of 100
# 17  This is a puzzle-adventure game of the the fea...  Metascore 66 out of 100
# 18  Jimmy Neutron: Attack of the Twonkies is jam-p...  Metascore 65 out of 100
# 19  State-of-the-art toilet humor! First graphic a...  Metascore 65 out of 100
# 20  Olde World, a multimillion dollar vacation spo...  Metascore 64 out of 100
# 21  The Adventures of Tintin is a game based off i...  Metascore 63 out of 100
# 22  You'll need to learn lock picking, security-co...  Metascore 63 out of 100
# 23  When Fred Reynolds left his fiancée at the air...  Metascore 61 out of 100
# 24  British nobleman, Samuel Gordon, has just retu...  Metascore 58 out of 100
# 25  A real-time surrealistic adventure in which th...  Metascore 58 out of 100
# 26  Sylvie, a young archaeologist, is about to beg...  Metascore 57 out of 100
# 27  The Ward has some good puzzles and some intere...  Metascore 57 out of 100
# 28  Adam Raichl is instantly killed in a horrific ...  Metascore 56 out of 100
# 29  Matt Simmons is a fresh recruit as a forensic ...  Metascore 54 out of 100
# 30  Gobliiins games mix elements of adventure and ...  Metascore 54 out of 100
# 31  As police detective Howard E. Loreid, players ...  Metascore 52 out of 100
# 32  In Sin City there are no secrets, only hidden ...  Metascore 51 out of 100
# 33  A brand-new tale, based on the fourth season o...  Metascore 51 out of 100
# 34  Hone your detective skills by interviewing wit...  Metascore 47 out of 100
# 35  CSI: Fatal Conspiracy features five new connec...  Metascore 42 out of 100
# 36  Based on the feature film adaptation of the be...  Metascore 39 out of 100
# 37  Play as any of the actual Pulau Tiga and Austr...  Metascore 26 out of 100

# %%
df_sales = pd.read_csv('Data/vgsales.csv')

# %%
df_sales
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
merged_df = pd.merge(final_df_3, df_sales, left_on='Title', right_on='Name', how='inner')

# %%
merged_df
# Out:
#                                                 Title          Date Rating  \
# 0           Zack & Wiki: Quest for Barbaros' Treasure  Oct 23, 2007      E
# 1                      Ghost Trick: Phantom Detective  Feb 12, 2009      E
# 2                                Hotel Dusk: Room 215  Oct 28, 2011      T
# 3   Teenage Zombies: Invasion of the Alien Brain T...  Sep 30, 2007   E10+
# 4                                       In Cold Blood  Apr 15, 2008      T
# 5                          Disney's A Christmas Carol   Feb 5, 2008      T
# 6   The Adventures of Jimmy Neutron Boy Genius: At...  Apr 15, 2008   E10+
# 7   The Adventures of Jimmy Neutron Boy Genius: At...  Apr 15, 2008   E10+
# 8   The Adventures of Jimmy Neutron Boy Genius: At...  Apr 15, 2008   E10+
# 9                  The Adventures of Tintin: The Game   Oct 9, 2007      E
# 10                 The Adventures of Tintin: The Game   Oct 9, 2007      E
# 11                 The Adventures of Tintin: The Game   Oct 9, 2007      E
# 12                 The Adventures of Tintin: The Game   Oct 9, 2007      E
# 13  Chronicles of Mystery: Curse of the Ancient Te...   Feb 5, 2008   E10+
# 14                                        Gobliiins 4  Mar 31, 1998      T
# 15                       Code Lyoko: Fall of X.A.N.A.   Jul 3, 2007      T
# 16                  Jake Hunter: Detective Chronicles  Jun 20, 2008      E
# 17                                           Inkheart  Jun 11, 2008      T
#
#                                           Description  \
# 0   Legend has it that a revered pirate named Barb...
# 1   Ghost Trick is a story of mystery and intrigue...
# 2   Los Angeles, 1979. You are Kyle Hyde, an ex-co...
# 3   The Earth is under attack by a horde of Alien ...
# 4   Travel the world controlling M16 Secret Britis...
# 5   This is a puzzle-adventure game of the the fea...
# 6   Jimmy Neutron: Attack of the Twonkies is jam-p...
# 7   Jimmy Neutron: Attack of the Twonkies is jam-p...
# 8   Jimmy Neutron: Attack of the Twonkies is jam-p...
# 9   The Adventures of Tintin is a game based off i...
# 10  The Adventures of Tintin is a game based off i...
# 11  The Adventures of Tintin is a game based off i...
# 12  The Adventures of Tintin is a game based off i...
# 13  Sylvie, a young archaeologist, is about to beg...
# 14  Gobliiins games mix elements of adventure and ...
# 15  A brand-new tale, based on the fourth season o...
# 16  Hone your detective skills by interviewing wit...
# 17  Based on the feature film adaptation of the be...
#
#                       Score   Rank  \
# 0   Metascore 87 out of 100   4655
# 1   Metascore 83 out of 100   4621
# 2   Metascore 78 out of 100   3578
# 3   Metascore 67 out of 100  13953
# 4   Metascore 67 out of 100  14659
# 5   Metascore 66 out of 100   6758
# 6   Metascore 65 out of 100   3949
# 7   Metascore 65 out of 100   3993
# 8   Metascore 65 out of 100   6202
# 9   Metascore 63 out of 100   5392
# 10  Metascore 63 out of 100   6322
# 11  Metascore 63 out of 100   6767
# 12  Metascore 63 out of 100   8764
# 13  Metascore 57 out of 100   7510
# 14  Metascore 54 out of 100  16373
# 15  Metascore 51 out of 100  11541
# 16  Metascore 47 out of 100  15285
# 17  Metascore 39 out of 100  15046
#
#                                                  Name Platform    Year  \
# 0           Zack & Wiki: Quest for Barbaros' Treasure      Wii  2007.0
# 1                      Ghost Trick: Phantom Detective       DS  2010.0
# 2                                Hotel Dusk: Room 215       DS  2007.0
# 3   Teenage Zombies: Invasion of the Alien Brain T...       DS  2008.0
# 4                                       In Cold Blood       PS  2000.0
# 5                          Disney's A Christmas Carol       DS  2009.0
# 6   The Adventures of Jimmy Neutron Boy Genius: At...      GBA  2004.0
# 7   The Adventures of Jimmy Neutron Boy Genius: At...      PS2  2004.0
# 8   The Adventures of Jimmy Neutron Boy Genius: At...       GC  2004.0
# 9                  The Adventures of Tintin: The Game      Wii  2011.0
# 10                 The Adventures of Tintin: The Game      PS3  2011.0
# 11                 The Adventures of Tintin: The Game     X360  2011.0
# 12                 The Adventures of Tintin: The Game      3DS  2011.0
# 13  Chronicles of Mystery: Curse of the Ancient Te...       DS  2009.0
# 14                                        Gobliiins 4       PC  2009.0
# 15                       Code Lyoko: Fall of X.A.N.A.       DS  2008.0
# 16                  Jake Hunter: Detective Chronicles       DS  2008.0
# 17                                           Inkheart       DS  2009.0
#
#         Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0   Adventure                     Nintendo      0.18      0.17      0.03
# 1   Adventure                       Capcom      0.20      0.08      0.12
# 2   Adventure                     Nintendo      0.27      0.05      0.22
# 3   Adventure       Ignition Entertainment      0.03      0.00      0.00
# 4   Adventure  Sony Computer Entertainment      0.02      0.01      0.00
# 5   Adventure   Disney Interactive Studios      0.22      0.01      0.00
# 6      Action                          THQ      0.36      0.13      0.00
# 7      Action                          THQ      0.24      0.19      0.00
# 8      Action                          THQ      0.22      0.06      0.00
# 9      Action                      Ubisoft      0.13      0.17      0.00
# 10     Action                      Ubisoft      0.06      0.16      0.00
# 11     Action                      Ubisoft      0.07      0.14      0.00
# 12     Action                      Ubisoft      0.05      0.09      0.00
# 13  Adventure             City Interactive      0.07      0.11      0.00
# 14  Adventure                Kalypso Media      0.00      0.01      0.00
# 15  Adventure                 Game Factory      0.07      0.00      0.00
# 16  Adventure                  Aksys Games      0.02      0.00      0.00
# 17  Adventure     DreamCatcher Interactive      0.02      0.00      0.00
#
#     Other_Sales  Global_Sales
# 0          0.04          0.42
# 1          0.03          0.42
# 2          0.03          0.56
# 3          0.00          0.04
# 4          0.00          0.03
# 5          0.02          0.25
# 6          0.01          0.50
# 7          0.06          0.50
# 8          0.01          0.28
# 9          0.04          0.34
# 10         0.05          0.27
# 11         0.03          0.25
# 12         0.02          0.15
# 13         0.02          0.20
# 14         0.00          0.01
# 15         0.01          0.08
# 16         0.00          0.02
# 17         0.00          0.02

# %%
len(merged_df)
# Out:
# 18
