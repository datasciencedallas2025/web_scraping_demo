# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time

# Set up headless Chrome browser
options = Options()
options.add_argument("--headless")  # Set to False to see browser in action
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# List to store all DataFrames
df_list = []

# Loop through pages 1 to 4
for page in range(1, 104):
    url = f"https://www.metacritic.com/browse/game/?releaseYearMin=1995&releaseYearMax=2025&genre=action&genre=action-adventure&genre=action-puzzle&genre=action-rpg&genre=adventure&genre=application&genre=arcade&genre=first---person-shooter&genre=rpg&genre=racing&genre=sports&genre=third---person-shooter&page={page}"
    print(f"Scraping page {page}...")
    
    driver.get(url)
    time.sleep(3)  # Wait for JavaScript to load

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Extract titles
    titles = soup.find_all('div', class_='c-finderProductCard_title')
    titles_a = [t.find_all("span")[1].text.strip() for t in titles if len(t.find_all("span")) > 1]

    # Extract dates and ratings
    dates = soup.find_all('div', class_='c-finderProductCard_meta')
    dates_a = []
    rates_a = []

    for d in dates:
        span_date = d.find('span', class_='u-text-uppercase')
        dates_a.append(span_date.text.strip() if span_date else None)

        span_rating = d.find('span', class_='u-text-capitalize')
        rates_a.append(span_rating.next_sibling.strip() if span_rating and span_rating.next_sibling else None)

    # Extract descriptions
    descriptions = soup.find_all('div', class_='c-finderProductCard_description')
    descriptions_a = [desc.find('span').text.strip() if desc.find('span') else None for desc in descriptions]

    # Extract scores
    scores = soup.find_all('div', class_='c-siteReviewScore')
    scores_a = [score.get("aria-label") for score in scores]

    # Debugging: check list lengths
    print(f"Titles: {len(titles_a)}, Dates: {len(dates_a)}, Ratings: {len(rates_a)}, Descriptions: {len(descriptions_a)}, Scores: {len(scores_a)}")

    # Trim to shortest length
    min_len = min(len(titles_a), len(dates_a), len(rates_a), len(descriptions_a), len(scores_a))

    data = zip(
        titles_a[:min_len],
        dates_a[:min_len],
        rates_a[:min_len],
        descriptions_a[:min_len],
        scores_a[:min_len]
    )

    # Create DataFrame
    df = pd.DataFrame(data, columns=['Title', 'Date', 'Rating', 'Description', 'Score'])
    df_list.append(df)

# Close the browser
driver.quit()

# Combine all data into one DataFrame
final_df = pd.concat(df_list, ignore_index=True)

# Display the first few rows
print(final_df.head())
# Out:
# Scraping page 1...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 2...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 3...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 4...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 5...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 6...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 7...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 8...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 9...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 10...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 11...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 12...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 13...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 14...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 15...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 16...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 17...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 18...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 19...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 20...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 21...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 22...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 23...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 24...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 25...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 26...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 27...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 28...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 29...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 30...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 31...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 32...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 33...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 34...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 35...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 36...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 37...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 38...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 39...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 40...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 41...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 42...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 43...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 44...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 45...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 46...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 47...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 48...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 49...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 50...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 51...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 52...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 53...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 54...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 55...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 56...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 57...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 58...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 59...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 60...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 61...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 62...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 63...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 64...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 65...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 66...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 67...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 68...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 69...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 70...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 71...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 72...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 73...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 74...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 75...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 76...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 77...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 78...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 79...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 80...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 81...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 82...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 83...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 84...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 85...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 86...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 87...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 88...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 89...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 90...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 91...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 92...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 93...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 94...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 95...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 96...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 97...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 98...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 99...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 100...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 101...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 102...
# Titles: 24, Dates: 48, Ratings: 48, Descriptions: 24, Scores: 24
# Scraping page 103...
# Titles: 9, Dates: 18, Ratings: 18, Descriptions: 9, Scores: 9
#                                  Title          Date Rating  \
# 0                           Elden Ring  Feb 25, 2022      M
# 1  Metal Gear Solid 2: Sons of Liberty          None   None
# 2    Elden Ring: Shadow of the Erdtree  Nov 12, 2001      M
# 3                   Ninja Gaiden Black          None   None
# 4                     Metal Gear Solid  Jun 21, 2024      M
#
#                                          Description                    Score
# 0  A New World Created By Hidetaka Miyazaki And G...  Metascore 96 out of 100
# 1  Since the incident on Shadow Moses Island, Met...  Metascore 96 out of 100
# 2  Rise, Tarnished, and let us walk a new path to...  Metascore 94 out of 100
# 3  In Ninja Gaiden Black you can reprise the role...  Metascore 94 out of 100
# 4  You are Snake, a government agent on a mission...  Metascore 94 out of 100

# %%
final_df.to_csv('output.csv', index = False)

# %%
final_df.dropna(inplace=True)

# %%
len(final_df)
# Out:
# 1009

# %%
df_sales = pd.read_csv('Data/vgsales.csv')

# %%
merged_df = pd.merge(final_df, df_sales, left_on='Title', right_on='Name', how='inner')

# %%
merged_df
# Out:
#                                        Title          Date Rating  \
# 360                                  Pac-Man   Aug 9, 2006      E
# 195                            Kinect Sports   Jun 6, 2017   E10+
# 0                           Metal Gear Solid  Jun 21, 2024      M
# 86              Monster Hunter Freedom Unite  Sep 12, 2006   E10+
# 134                  The Simpsons: Hit & Run   Jul 5, 2010      T
# ..                                       ...           ...    ...
# 80                 Marvel: Ultimate Alliance   Nov 4, 2008      E
# 376                            Darkened Skye  Oct 29, 2003      M
# 249  Harry Potter and the Chamber of Secrets  Feb 22, 2018      E
# 397                Spider-Man: Friend or Foe  Aug 12, 2008      T
# 535             Aquaman: Battle for Atlantis  Nov 27, 2001      M
#
#                                            Description  \
# 360  [Xbox Live Arcade]  Play one of the all-time c...
# 195  This action sports compilation for the Xbox 36...
# 0    You are Snake, a government agent on a mission...
# 86   The Monster Hunter world is always changing an...
# 134  The Simpsons Hit & Run is a mission-based driv...
# ..                                                 ...
# 80   Marvel: Ultimate Alliance is an action/RPG tha...
# 376  The dread lord Necroth rules the world armed w...
# 249  Players enter fantastical free-roaming 3D envi...
# 397  Spider-Man: Friend or Foe challenges players t...
# 535  Here's your chance to wield the power of Aquam...
#
#                        Score   Rank                                     Name  \
# 360  Metascore 62 out of 100     90                                  Pac-Man
# 195  Metascore 73 out of 100    140                            Kinect Sports
# 0    Metascore 94 out of 100    146                         Metal Gear Solid
# 86   Metascore 81 out of 100    162             Monster Hunter Freedom Unite
# 134  Metascore 78 out of 100    225                  The Simpsons: Hit & Run
# ..                       ...    ...                                      ...
# 80   Metascore 82 out of 100  16236                Marvel: Ultimate Alliance
# 376  Metascore 61 out of 100  16390                            Darkened Skye
# 249  Metascore 71 out of 100  16146  Harry Potter and the Chamber of Secrets
# 397  Metascore 60 out of 100  16224                Spider-Man: Friend or Foe
# 535  Metascore 26 out of 100  16252             Aquaman: Battle for Atlantis
#
#     Platform    Year         Genre                     Publisher  NA_Sales  \
# 360     2600  1982.0        Puzzle                         Atari      7.28
# 195     X360  2010.0        Sports        Microsoft Game Studios      3.92
# 0         PS  1998.0        Action  Konami Digital Entertainment      3.18
# 86       PSP  2008.0  Role-Playing                        Capcom      0.47
# 134      PS2  2003.0        Racing                 Vivendi Games      1.73
# ..       ...     ...           ...                           ...       ...
# 80        PC  2006.0  Role-Playing                    Activision      0.01
# 376       GC  2002.0     Adventure                TDK Mediactive      0.01
# 249       PC  2002.0        Action               Electronic Arts      0.00
# 397       PC  2007.0        Action                    Activision      0.01
# 535       GC  2003.0        Action                TDK Mediactive      0.01
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 360      0.45      0.00         0.08          7.81
# 195      1.78      0.03         0.51          6.24
# 0        1.83      0.78         0.24          6.03
# 86       0.57      4.13         0.34          5.50
# 134      2.19      0.00         0.79          4.70
# ..        ...       ...          ...           ...
# 80       0.00      0.00         0.00          0.01
# 376      0.00      0.00         0.00          0.01
# 249      0.01      0.00         0.00          0.01
# 397      0.00      0.00         0.00          0.01
# 535      0.00      0.00         0.00          0.01
#
# [536 rows x 16 columns]

# %%
len(merged_df)
# Out:
# 536

# %%
merged_df.sort_values(by='Global_Sales', ascending=False, inplace=True)
merged_df
# Out:
#                                        Title          Date Rating  \
# 360                                  Pac-Man   Aug 9, 2006      E
# 195                            Kinect Sports   Jun 6, 2017   E10+
# 0                           Metal Gear Solid  Jun 21, 2024      M
# 86              Monster Hunter Freedom Unite  Sep 12, 2006   E10+
# 134                  The Simpsons: Hit & Run   Jul 5, 2010      T
# ..                                       ...           ...    ...
# 80                 Marvel: Ultimate Alliance   Nov 4, 2008      E
# 376                            Darkened Skye  Oct 29, 2003      M
# 249  Harry Potter and the Chamber of Secrets  Feb 22, 2018      E
# 397                Spider-Man: Friend or Foe  Aug 12, 2008      T
# 535             Aquaman: Battle for Atlantis  Nov 27, 2001      M
#
#                                            Description  \
# 360  [Xbox Live Arcade]  Play one of the all-time c...
# 195  This action sports compilation for the Xbox 36...
# 0    You are Snake, a government agent on a mission...
# 86   The Monster Hunter world is always changing an...
# 134  The Simpsons Hit & Run is a mission-based driv...
# ..                                                 ...
# 80   Marvel: Ultimate Alliance is an action/RPG tha...
# 376  The dread lord Necroth rules the world armed w...
# 249  Players enter fantastical free-roaming 3D envi...
# 397  Spider-Man: Friend or Foe challenges players t...
# 535  Here's your chance to wield the power of Aquam...
#
#                        Score   Rank                                     Name  \
# 360  Metascore 62 out of 100     90                                  Pac-Man
# 195  Metascore 73 out of 100    140                            Kinect Sports
# 0    Metascore 94 out of 100    146                         Metal Gear Solid
# 86   Metascore 81 out of 100    162             Monster Hunter Freedom Unite
# 134  Metascore 78 out of 100    225                  The Simpsons: Hit & Run
# ..                       ...    ...                                      ...
# 80   Metascore 82 out of 100  16236                Marvel: Ultimate Alliance
# 376  Metascore 61 out of 100  16390                            Darkened Skye
# 249  Metascore 71 out of 100  16146  Harry Potter and the Chamber of Secrets
# 397  Metascore 60 out of 100  16224                Spider-Man: Friend or Foe
# 535  Metascore 26 out of 100  16252             Aquaman: Battle for Atlantis
#
#     Platform    Year         Genre                     Publisher  NA_Sales  \
# 360     2600  1982.0        Puzzle                         Atari      7.28
# 195     X360  2010.0        Sports        Microsoft Game Studios      3.92
# 0         PS  1998.0        Action  Konami Digital Entertainment      3.18
# 86       PSP  2008.0  Role-Playing                        Capcom      0.47
# 134      PS2  2003.0        Racing                 Vivendi Games      1.73
# ..       ...     ...           ...                           ...       ...
# 80        PC  2006.0  Role-Playing                    Activision      0.01
# 376       GC  2002.0     Adventure                TDK Mediactive      0.01
# 249       PC  2002.0        Action               Electronic Arts      0.00
# 397       PC  2007.0        Action                    Activision      0.01
# 535       GC  2003.0        Action                TDK Mediactive      0.01
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 360      0.45      0.00         0.08          7.81
# 195      1.78      0.03         0.51          6.24
# 0        1.83      0.78         0.24          6.03
# 86       0.57      4.13         0.34          5.50
# 134      2.19      0.00         0.79          4.70
# ..        ...       ...          ...           ...
# 80       0.00      0.00         0.00          0.01
# 376      0.00      0.00         0.00          0.01
# 249      0.01      0.00         0.00          0.01
# 397      0.00      0.00         0.00          0.01
# 535      0.00      0.00         0.00          0.01
#
# [536 rows x 16 columns]

# %%
merged_df.reset_index(drop=True, inplace=True)
merged_df
# Out:
#                                        Title          Date Rating  \
# 0                                    Pac-Man   Aug 9, 2006      E
# 1                              Kinect Sports   Jun 6, 2017   E10+
# 2                           Metal Gear Solid  Jun 21, 2024      M
# 3               Monster Hunter Freedom Unite  Sep 12, 2006   E10+
# 4                    The Simpsons: Hit & Run   Jul 5, 2010      T
# ..                                       ...           ...    ...
# 531                Marvel: Ultimate Alliance   Nov 4, 2008      E
# 532                            Darkened Skye  Oct 29, 2003      M
# 533  Harry Potter and the Chamber of Secrets  Feb 22, 2018      E
# 534                Spider-Man: Friend or Foe  Aug 12, 2008      T
# 535             Aquaman: Battle for Atlantis  Nov 27, 2001      M
#
#                                            Description  \
# 0    [Xbox Live Arcade]  Play one of the all-time c...
# 1    This action sports compilation for the Xbox 36...
# 2    You are Snake, a government agent on a mission...
# 3    The Monster Hunter world is always changing an...
# 4    The Simpsons Hit & Run is a mission-based driv...
# ..                                                 ...
# 531  Marvel: Ultimate Alliance is an action/RPG tha...
# 532  The dread lord Necroth rules the world armed w...
# 533  Players enter fantastical free-roaming 3D envi...
# 534  Spider-Man: Friend or Foe challenges players t...
# 535  Here's your chance to wield the power of Aquam...
#
#                        Score   Rank                                     Name  \
# 0    Metascore 62 out of 100     90                                  Pac-Man
# 1    Metascore 73 out of 100    140                            Kinect Sports
# 2    Metascore 94 out of 100    146                         Metal Gear Solid
# 3    Metascore 81 out of 100    162             Monster Hunter Freedom Unite
# 4    Metascore 78 out of 100    225                  The Simpsons: Hit & Run
# ..                       ...    ...                                      ...
# 531  Metascore 82 out of 100  16236                Marvel: Ultimate Alliance
# 532  Metascore 61 out of 100  16390                            Darkened Skye
# 533  Metascore 71 out of 100  16146  Harry Potter and the Chamber of Secrets
# 534  Metascore 60 out of 100  16224                Spider-Man: Friend or Foe
# 535  Metascore 26 out of 100  16252             Aquaman: Battle for Atlantis
#
#     Platform    Year         Genre                     Publisher  NA_Sales  \
# 0       2600  1982.0        Puzzle                         Atari      7.28
# 1       X360  2010.0        Sports        Microsoft Game Studios      3.92
# 2         PS  1998.0        Action  Konami Digital Entertainment      3.18
# 3        PSP  2008.0  Role-Playing                        Capcom      0.47
# 4        PS2  2003.0        Racing                 Vivendi Games      1.73
# ..       ...     ...           ...                           ...       ...
# 531       PC  2006.0  Role-Playing                    Activision      0.01
# 532       GC  2002.0     Adventure                TDK Mediactive      0.01
# 533       PC  2002.0        Action               Electronic Arts      0.00
# 534       PC  2007.0        Action                    Activision      0.01
# 535       GC  2003.0        Action                TDK Mediactive      0.01
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0        0.45      0.00         0.08          7.81
# 1        1.78      0.03         0.51          6.24
# 2        1.83      0.78         0.24          6.03
# 3        0.57      4.13         0.34          5.50
# 4        2.19      0.00         0.79          4.70
# ..        ...       ...          ...           ...
# 531      0.00      0.00         0.00          0.01
# 532      0.00      0.00         0.00          0.01
# 533      0.01      0.00         0.00          0.01
# 534      0.00      0.00         0.00          0.01
# 535      0.00      0.00         0.00          0.01
#
# [536 rows x 16 columns]

# %%
merged_df.sort_values(by='Global_Sales', ascending=False, inplace=True)
merged_df
# Out:
#                                        Title          Date Rating  \
# 0                                    Pac-Man   Aug 9, 2006      E
# 1                              Kinect Sports   Jun 6, 2017   E10+
# 2                           Metal Gear Solid  Jun 21, 2024      M
# 3               Monster Hunter Freedom Unite  Sep 12, 2006   E10+
# 4                    The Simpsons: Hit & Run   Jul 5, 2010      T
# ..                                       ...           ...    ...
# 531                Marvel: Ultimate Alliance   Nov 4, 2008      E
# 532                            Darkened Skye  Oct 29, 2003      M
# 533  Harry Potter and the Chamber of Secrets  Feb 22, 2018      E
# 534                Spider-Man: Friend or Foe  Aug 12, 2008      T
# 535             Aquaman: Battle for Atlantis  Nov 27, 2001      M
#
#                                            Description  \
# 0    [Xbox Live Arcade]  Play one of the all-time c...
# 1    This action sports compilation for the Xbox 36...
# 2    You are Snake, a government agent on a mission...
# 3    The Monster Hunter world is always changing an...
# 4    The Simpsons Hit & Run is a mission-based driv...
# ..                                                 ...
# 531  Marvel: Ultimate Alliance is an action/RPG tha...
# 532  The dread lord Necroth rules the world armed w...
# 533  Players enter fantastical free-roaming 3D envi...
# 534  Spider-Man: Friend or Foe challenges players t...
# 535  Here's your chance to wield the power of Aquam...
#
#                        Score   Rank                                     Name  \
# 0    Metascore 62 out of 100     90                                  Pac-Man
# 1    Metascore 73 out of 100    140                            Kinect Sports
# 2    Metascore 94 out of 100    146                         Metal Gear Solid
# 3    Metascore 81 out of 100    162             Monster Hunter Freedom Unite
# 4    Metascore 78 out of 100    225                  The Simpsons: Hit & Run
# ..                       ...    ...                                      ...
# 531  Metascore 82 out of 100  16236                Marvel: Ultimate Alliance
# 532  Metascore 61 out of 100  16390                            Darkened Skye
# 533  Metascore 71 out of 100  16146  Harry Potter and the Chamber of Secrets
# 534  Metascore 60 out of 100  16224                Spider-Man: Friend or Foe
# 535  Metascore 26 out of 100  16252             Aquaman: Battle for Atlantis
#
#     Platform    Year         Genre                     Publisher  NA_Sales  \
# 0       2600  1982.0        Puzzle                         Atari      7.28
# 1       X360  2010.0        Sports        Microsoft Game Studios      3.92
# 2         PS  1998.0        Action  Konami Digital Entertainment      3.18
# 3        PSP  2008.0  Role-Playing                        Capcom      0.47
# 4        PS2  2003.0        Racing                 Vivendi Games      1.73
# ..       ...     ...           ...                           ...       ...
# 531       PC  2006.0  Role-Playing                    Activision      0.01
# 532       GC  2002.0     Adventure                TDK Mediactive      0.01
# 533       PC  2002.0        Action               Electronic Arts      0.00
# 534       PC  2007.0        Action                    Activision      0.01
# 535       GC  2003.0        Action                TDK Mediactive      0.01
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0        0.45      0.00         0.08          7.81
# 1        1.78      0.03         0.51          6.24
# 2        1.83      0.78         0.24          6.03
# 3        0.57      4.13         0.34          5.50
# 4        2.19      0.00         0.79          4.70
# ..        ...       ...          ...           ...
# 531      0.00      0.00         0.00          0.01
# 532      0.00      0.00         0.00          0.01
# 533      0.01      0.00         0.00          0.01
# 534      0.00      0.00         0.00          0.01
# 535      0.00      0.00         0.00          0.01
#
# [536 rows x 16 columns]

# %%
merged_df.to_csv('output_B.csv', index = False)
